# %% [markdown]
# #  Aadhaar Data-Driven Innovation: Infrastructure Capacity & Trends

# %% [markdown]
# ![image.png](attachment:54d341d2-a9d5-46e3-900a-f76f58255a4f.png)

# %% [markdown]
# ###   Dataset Overview
# > The project utilizes three primary anonymized datasets: Biometrics, Enrollment, and Demographics. All datasets are linked by common keys: Date, State, District, and Pincode.
#
# **Dataset ; Record_Count  ;Total_Transactions**
# * **Enrollment  ; 1,006,029   ; 51,222,945**
# * **Demographics ; 2,071,700  ;  6,651,618**

# %% [markdown]
# # **Date Range :-**
# **January 3, 2025 – December 12, 2025.**

# %% [markdown]
# #  Biometrics Dataset (df_bio)
#
# **Tracks biometric update activities categorized by age groups.**
#
# * **Columns: date, state, district, pincode, bio_age_5_17, bio_age_17_.**
#
# #  Enrollment Dataset (df_enroll)
# **Tracks new Aadhaar enrollments categorized by age.**
#
# * **Columns: date, state, district, pincode, age_0_5, age_5_17, age_18_greater.**
#
# #  Demographics Dataset (df_demo)
#
# **Tracks demographic-related updates (e.g., address, name).**
#
# * **Columns: date, state, district, pincode, demo_age_5_17, demo_age_17_.**

# %% [markdown]
# #    Geographic Coverage
# **The dataset spans across India, covering a wide range of administrative regions:**
#
# * States/UTs: 36.
# * Districts: 1,028.
# * Pincodes: 19,814.
#
#
# #  Data Completeness
# **Upon merging all three datasets, 25.67% of the resulting records contain synchronized data for biometrics, enrollment, and demographics for the same location and date.**

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Import Libraries</h3>
# </div>

# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
pd.options.display.float_format = lambda x: ('%f' % x).rstrip('0').rstrip('.') if not pd.isna(x) else ''

import warnings
warnings.filterwarnings(
    "ignore",
    message="Parsing dates in .* dayfirst=False"
)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Load Data</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Load Data</h3>
# </div>

# %%
df_bio = pd.read_csv("finalBiometrics.csv")
df_enroll = pd.read_csv("finalEnrollment.csv")
df_demo = pd.read_csv("finalDemographics.csv")

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Data Preview</h3>
# </div>

# %%
df_bio.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
df_enroll.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df_demo.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Min Date
#         Max Date</h3>
# </div>

# %%
for name, df in [("Bio", df_bio), ("Enroll", df_enroll), ("Demo", df_demo)]:
    print(name, "min date:", df["date"].min())
    print(name, "max date:", df["date"].max())
    print()
# Out:
# Bio min date: 01-03-2025
# Bio max date: 31-10-2025
#
# Enroll min date: 01-04-2025
# Enroll max date: 31-12-2025
#
# Demo min date: 01-03-2025
# Demo max date: 31-10-2025

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Temporal Consistency & Timeline Analysis</h3>
# </div>

# %%
dfs = [("Bio", df_bio), ("Enroll", df_enroll), ("Demo", df_demo)]
stats = []

for name, df_single in dfs:
    dates = pd.to_datetime(df_single["date"], errors="coerce").dropna().dt.date
    
    if len(dates) == 0:
        stats.append({
            "Dataset": name,
            "Min Date": pd.NaT,
            "Max Date": pd.NaT,
            "Mean Jump (days)": pd.NA
        })
        continue

    dates = pd.Series(sorted(dates)).drop_duplicates()
    
    jumps = dates.diff().dropna().apply(lambda x: x.days)
    
    jumps = jumps[jumps > 0]
    
    stats.append({
        "Dataset": name,
        "Min Date": dates.min(),
        "Max Date": dates.max(),
        "Mean Jump (days)": jumps.mean() if not jumps.empty else pd.NA
    })

summary_df = pd.DataFrame(stats)
summary_df
# Out:
#   Dataset    Min Date    Max Date  Mean Jump (days)
# 0     Bio  2025-01-03  2025-12-12             8.575
# 1  Enroll  2025-01-04  2025-12-11         11.758621
# 2    Demo  2025-01-03  2025-12-12             8.575

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">rows and columns</h3>
# </div>

# %%
df_bio.shape,df_enroll.shape,df_demo.shape
# Out:
# ((1861108, 6), (1006029, 7), (2071700, 6))

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Data Integration: Multi-Source Merging</h3>
# </div>

# %%
keys = ["date", "state", "district", "pincode"]

df = df_bio.merge(df_enroll, on=keys, how="outer")
df = df.merge(df_demo, on=keys, how="outer")

# %%
df
# Out:
#                date                        state        district  pincode  \
# 0        01-03-2025    Andaman & Nicobar Islands        Andamans   744101
# 1        01-03-2025  Andaman and Nicobar Islands         Nicobar   744301
# 2        01-03-2025  Andaman and Nicobar Islands         Nicobar   744301
# 3        01-03-2025  Andaman and Nicobar Islands         Nicobar   744302
# 4        01-03-2025  Andaman and Nicobar Islands         Nicobar   744303
# ...             ...                          ...             ...      ...
# 2947676  31-12-2025                  West Bengal  West Midnapore   721426
# 2947677  31-12-2025                  West Bengal  West Midnapore   721504
# 2947678  31-12-2025                  West Bengal  West Midnapore   721506
# 2947679  31-12-2025                  West Bengal  West Midnapore   721507
# 2947680  31-12-2025                  West Bengal  West Midnapore   721517
#
#          bio_age_5_17  bio_age_17_  age_0_5  age_5_17  age_18_greater  \
# 0                  16          193      NaN       NaN             NaN
# 1                 101           48      NaN       NaN             NaN
# 2                 101           48      NaN       NaN             NaN
# 3                  15           12      NaN       NaN             NaN
# 4                  46           27      NaN       NaN             NaN
# ...               ...          ...      ...       ...             ...
# 2947676           NaN          NaN        0         1               0
# 2947677           NaN          NaN        1         0               0
# 2947678           NaN          NaN        1         1               0
# 2947679           NaN          NaN        1         0               0
# 2947680           NaN          NaN        2         1               0
#
#          demo_age_5_17  demo_age_17_
# 0                  NaN           NaN
# 1                   16           180
# 2                   16           180
# 3                  NaN           NaN
# 4                  NaN           NaN
# ...                ...           ...
# 2947676            NaN           NaN
# 2947677            NaN           NaN
# 2947678            NaN           NaN
# 2947679            NaN           NaN
# 2947680            NaN           NaN
#
# [2947681 rows x 11 columns]

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Feature Engineering: Metric Aggregation</h3>
# </div>

# %%
bio_cols = ["bio_age_5_17", "bio_age_17_"]
enroll_cols = ["demo_age_5_17", "demo_age_17_"]
demo_cols = ["age_0_5", "age_5_17", "age_18_greater"]

df["total_biometrics"] = df[bio_cols].mask(df[bio_cols] == -1).sum(axis=1, skipna=True)
df["total_biometrics"] = df["total_biometrics"].where(df[bio_cols].notna().any(axis=1), pd.NA)

df["total_enrollment"] = df[enroll_cols].mask(df[enroll_cols] == -1).sum(axis=1, skipna=True)
df["total_enrollment"] = df["total_enrollment"].where(df[enroll_cols].notna().any(axis=1), pd.NA)

df["total_demographics"] = df[demo_cols].mask(df[demo_cols] == -1).sum(axis=1, skipna=True)
df["total_demographics"] = df["total_demographics"].where(df[demo_cols].notna().any(axis=1), pd.NA)

# %%
df = df[
    [
        "date", "state", "district", "pincode",
        "bio_age_5_17", "bio_age_17_", "total_biometrics",
        "demo_age_5_17", "demo_age_17_", "total_enrollment",
        "age_0_5", "age_5_17", "age_18_greater", "total_demographics"
    ]
]

# %%
df.head()
# Out:
#          date                        state  district  pincode  bio_age_5_17  \
# 0  01-03-2025    Andaman & Nicobar Islands  Andamans   744101            16
# 1  01-03-2025  Andaman and Nicobar Islands   Nicobar   744301           101
# 2  01-03-2025  Andaman and Nicobar Islands   Nicobar   744301           101
# 3  01-03-2025  Andaman and Nicobar Islands   Nicobar   744302            15
# 4  01-03-2025  Andaman and Nicobar Islands   Nicobar   744303            46
#
#    bio_age_17_  total_biometrics  demo_age_5_17  demo_age_17_  \
# 0          193               209            NaN           NaN
# 1           48               149             16           180
# 2           48               149             16           180
# 3           12                27            NaN           NaN
# 4           27                73            NaN           NaN
#
#    total_enrollment  age_0_5  age_5_17  age_18_greater  total_demographics
# 0               NaN      NaN       NaN             NaN                 NaN
# 1               196      NaN       NaN             NaN                 NaN
# 2               196      NaN       NaN             NaN                 NaN
# 3               NaN      NaN       NaN             NaN                 NaN
# 4               NaN      NaN       NaN             NaN                 NaN

# %%
df.shape
# Out:
# (2947681, 14)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">  Data Cleaning & Integrity Audit</h3>
# </div>

# %%
num_cols = ["bio_age_5_17","bio_age_17_",
            "demo_age_5_17","demo_age_17_",
            "age_0_5","age_5_17","age_18_greater",
            "total_biometrics","total_enrollment","total_demographics"]

complete_rows = df[df[num_cols].notna().all(axis=1)]

completion_pct = (len(complete_rows) / len(df)) * 100
print("Complete Rows :", round(completion_pct, 2), "%")
# Out:
# Complete Rows : 25.67 %

# %%
df['state'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Jammu And Kashmir', 'Jammu & Kashmir', 'ODISHA', 'WEST BENGAL',
#        'WESTBENGAL', 'West  Bengal', 'West bengal', 'Westbengal',
#        'andhra pradesh', 'odisha', 'west Bengal', 'West Bangal', '100000',
#        'West Bengli', 'Chhatisgarh', 'Uttaranchal', 'BALANAGAR',
#        'Darbhanga', 'Puttenahalli', 'Nagpur', 'Jaipur',
#        'Raja Annamalai Puram', 'Madanapalle', 'Tamilnadu'], dtype=object)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">State Name Canonicalization</h3>
# </div>

# %%
df["state"] = df["state"].str.lower().str.replace(r"\s+", " ", regex=True)

STATE_CANONICAL_MAP = {
    "pondicherry": "Puducherry",
    "puducherry": "Puducherry",
    
    "daman and diu": "Dadra And Nagar Haveli And Daman And Diu",
    "daman & diu": "Dadra And Nagar Haveli And Daman And Diu",
    "dadra and nagar haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "dadra & nagar haveli": "Dadra And Nagar Haveli And Daman And Diu",
    "dadra and nagar haveli and daman and diu":
        "Dadra And Nagar Haveli And Daman And Diu",
    "the dadra and nagar haveli and daman and diu":
        "Dadra And Nagar Haveli And Daman And Diu",

    "west bengal": "West Bengal",
    "west bangal": "West Bengal",
    "west bengli": "West Bengal",
    "westbengal": "West Bengal",
    "west  bengal": "West Bengal",

    "orissa": "Odisha",

    "tamilnadu": "Tamil Nadu",
    "tamil nadu": "Tamil Nadu",

    "uttaranchal": "Uttarakhand",

    "chhatisgarh": "Chhattisgarh",
    "chhattisgarh": "Chhattisgarh",

    "jammu & kashmir": "Jammu And Kashmir",
    "jammu and kashmir": "Jammu And Kashmir",

    "andaman & nicobar islands": "Andaman And Nicobar Islands",
    "andaman and nicobar islands": "Andaman And Nicobar Islands",

    "darbhanga": "Bihar",
    "nagpur": "Maharashtra",
    "jaipur": "Rajasthan",
    "balanagar": "Telangana",
    "puttenahalli": "Karnataka",
    "raja annamalai puram": "Tamil Nadu",
    "madanapalle": "Andhra Pradesh",
}

df["state"] = df["state"].replace(STATE_CANONICAL_MAP).str.title()

# %%
df.drop(df[df["state"] == "100000"].index, inplace=True)

# %%
df['state'].unique()
# Out:
# array(['Andaman And Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra And Nagar Haveli And Daman And Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu And Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Dataset Executive Summary</h3>
# </div>

# %%
print(f"Total records: {len(df):,}")

print(f"Total biometric transactions: {df['total_biometrics'].sum(skipna=True):,}")
print(f"Total enrollment transactions: {df['total_enrollment'].sum(skipna=True):,}")
print(f"Total demographic counts: {df['total_demographics'].sum(skipna=True):,}")

valid_dates = pd.to_datetime(df['date'], errors='coerce').dropna()
print("\nDate range:")
print(f"From {valid_dates.min().date()} to {valid_dates.max().date()}")

print("\nNumber of states/UTs:", df["state"].nunique(dropna=True))
print("Number of districts:", df["district"].nunique(dropna=True))
print("Number of pincodes:", df["pincode"].nunique(dropna=True))
# Out:
# Total records: 2,947,657
# Total biometric transactions: 81,107,526.0
# Total enrollment transactions: 51,222,945.0
# Total demographic counts: 6,651,618.0
#
# Date range:
# From 2025-01-03 to 2025-12-12
#
# Number of states/UTs: 36
# Number of districts: 1028
# Number of pincodes: 19814

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Regional Performance Benchmarking</h3>
# </div>

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]

for total_col in totals:
    state_total = df.groupby("state")[total_col].sum().sort_values(ascending=False)
    state_share = (state_total / state_total.sum()) * 100
    
    display(Markdown(f"<h3 style='text-align:center; padding: 10px;'><b>🥇 Top 10 States: {total_col.replace('_',' ').title()}</b></h3>"))
    
    ranking_df = pd.DataFrame({
        "Total Count": state_total.head(10).map('{:,}'.format),
        "National Share (%)": state_share.head(10).map('{:.2f}%'.format)
    })
    display(ranking_df)
    
    display(Markdown(f"<h3 style='text-align:center; padding: 10px;'><b>🔻 Bottom 10 States: {total_col.replace('_',' ').title()}</b></h3>"))
    
    bottom_df = pd.DataFrame({
        "Total Count": state_total.tail(10).map('{:,}'.format),
        "National Share (%)": state_share.tail(10).map('{:.2f}%'.format)
    })
    display(bottom_df)
# Out:
# <h3 style='text-align:center; padding: 10px;'><b>🥇 Top 10 States: Total Biometrics</b></h3>
#                  Total Count National Share (%)
# state
# Uttar Pradesh   10,929,837.0             13.48%
# Maharashtra     10,595,450.0             13.06%
# Madhya Pradesh   7,129,250.0              8.79%
# Bihar            5,568,926.0              6.87%
# Tamil Nadu       5,379,226.0              6.63%
# Rajasthan        4,720,788.0              5.82%
# Andhra Pradesh   4,348,843.0              5.36%
# Gujarat          3,637,123.0              4.48%
# Chhattisgarh     3,241,343.0              4.00%
# Karnataka        3,045,852.0              3.76%
# <h3 style='text-align:center; padding: 10px;'><b>🔻 Bottom 10 States: Total Biometrics</b></h3>
#                                          Total Count National Share (%)
# state
# Chandigarh                                 102,137.0              0.13%
# Meghalaya                                   98,412.0              0.12%
# Arunachal Pradesh                           81,784.0              0.10%
# Puducherry                                  79,284.0              0.10%
# Goa                                         75,223.0              0.09%
# Dadra And Nagar Haveli And Daman And Diu    44,638.0              0.06%
# Sikkim                                      24,826.0              0.03%
# Andaman And Nicobar Islands                 23,328.0              0.03%
# Ladakh                                       6,517.0              0.01%
# Lakshadweep                                  5,092.0              0.01%
# <h3 style='text-align:center; padding: 10px;'><b>🥇 Top 10 States: Total Enrollment</b></h3>
#                 Total Count National Share (%)
# state
# Uttar Pradesh   8,863,254.0             17.30%
# Maharashtra     5,241,978.0             10.23%
# Bihar           5,128,088.0             10.01%
# West Bengal     4,035,467.0              7.88%
# Madhya Pradesh  2,979,860.0              5.82%
# Rajasthan       2,898,975.0              5.66%
# Andhra Pradesh  2,383,026.0              4.65%
# Tamil Nadu      2,309,389.0              4.51%
# Chhattisgarh    2,091,945.0              4.08%
# Gujarat         1,904,678.0              3.72%
# <h3 style='text-align:center; padding: 10px;'><b>🔻 Bottom 10 States: Total Enrollment</b></h3>
#                                          Total Count National Share (%)
# state
# Mizoram                                     42,838.0              0.08%
# Arunachal Pradesh                           38,537.0              0.08%
# Nagaland                                    37,836.0              0.07%
# Goa                                         36,801.0              0.07%
# Puducherry                                  33,687.0              0.07%
# Sikkim                                      20,838.0              0.04%
# Dadra And Nagar Haveli And Daman And Diu    12,564.0              0.02%
# Andaman And Nicobar Islands                  7,554.0              0.01%
# Ladakh                                       5,936.0              0.01%
# Lakshadweep                                  1,204.0              0.00%
# <h3 style='text-align:center; padding: 10px;'><b>🥇 Top 10 States: Total Demographics</b></h3>
#                 Total Count National Share (%)
# state
# Uttar Pradesh   1,244,394.0             18.71%
# Bihar             736,142.0             11.07%
# Madhya Pradesh    616,502.0              9.27%
# West Bengal       463,080.0              6.96%
# Maharashtra       457,885.0              6.88%
# Rajasthan         423,114.0              6.36%
# Gujarat           332,746.0              5.00%
# Tamil Nadu        273,271.0              4.11%
# Assam             271,122.0              4.08%
# Karnataka         265,246.0              3.99%
# <h3 style='text-align:center; padding: 10px;'><b>🔻 Bottom 10 States: Total Demographics</b></h3>
#                                          Total Count National Share (%)
# state
# Mizoram                                      7,036.0              0.11%
# Arunachal Pradesh                            5,348.0              0.08%
# Puducherry                                   3,666.0              0.06%
# Chandigarh                                   3,538.0              0.05%
# Goa                                          2,832.0              0.04%
# Sikkim                                       2,571.0              0.04%
# Dadra And Nagar Haveli And Daman And Diu     2,010.0              0.03%
# Ladakh                                         743.0              0.01%
# Andaman And Nicobar Islands                    628.0              0.01%
# Lakshadweep                                    237.0              0.00%

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Regional Demand Distribution</h3>
# </div>

# %%
colors = ["#2e7d32", "#1976d2", "#f57c00"]
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]

for total_col, title, color in zip(totals, titles, colors):
    state_total = df.groupby("state")[total_col].sum().sort_values(ascending=False)
    top10 = state_total.head(10)

    plt.figure(figsize=(12,6))
    top10.plot(kind="bar", color=color, edgecolor='black', alpha=0.8)
    
    plt.title(f"🏆 Top 10 States: {title}", fontsize=15, fontweight='bold', pad=20)
    plt.ylabel("Total Transactions (Millions)", fontsize=12)
    plt.xlabel("State", fontsize=12)
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis="y", linestyle="--", alpha=0.3)
    
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\mohds\AppData\Local\Temp\ipykernel_16548\574267508.py:21: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mohds\AppData\Local\Temp\ipykernel_16548\574267508.py:21: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mohds\AppData\Local\Temp\ipykernel_16548\574267508.py:21: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Infrastructure High-Load Audit</h3>
# </div>

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]

for total_col, title in zip(totals, titles):
    threshold = df[total_col].dropna().quantile(0.90)
    
    high_load_col = f"high_load_{total_col}"
    df[high_load_col] = df[total_col].where(df[total_col].notna())
    df[high_load_col] = df[high_load_col].apply(lambda x: 1 if x >= threshold else 0 if pd.notna(x) else pd.NA)
    
    state_highload = df.groupby("state")[high_load_col].mean().sort_values(ascending=False)
    
    display(Markdown(f"<h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>⚠️ High-Load Risk: {title} (Top 10)</b></h3>"))
    
    high_risk_df = pd.DataFrame(state_highload.head(10)).rename(columns={high_load_col: "Stress Ratio"})
    display(high_risk_df.style.background_gradient(cmap='Reds'))
    
    display(Markdown(f"<h3 style='text-align:center; border: 1px solid #ddd; padding: 10px;'><b>✅ Operational Stability: {title} (Bottom 10)</b></h3>"))
    
    low_risk_df = pd.DataFrame(state_highload.tail(10)).rename(columns={high_load_col: "Stress Ratio"})
    display(low_risk_df)
    
    print("\n" + "-"*50 + "\n")
# Out:
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>⚠️ High-Load Risk: Biometric Usage (Top 10)</b></h3>
# <style type="text/css">
# </style>
# <table id="T_d0133">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0133_level0_col0" class="col_heading level0 col0" >Stress Ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0133_level0_row0" class="row_heading level0 row0" >Delhi</th>
#       <td id="T_d0133_row0_col0" class="data row0 col0" >0.292858</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row1" class="row_heading level0 row1" >Chhattisgarh</th>
#       <td id="T_d0133_row1_col0" class="data row1 col0" >0.291736</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row2" class="row_heading level0 row2" >Maharashtra</th>
#       <td id="T_d0133_row2_col0" class="data row2 col0" >0.203474</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row3" class="row_heading level0 row3" >Madhya Pradesh</th>
#       <td id="T_d0133_row3_col0" class="data row3 col0" >0.181836</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row4" class="row_heading level0 row4" >Haryana</th>
#       <td id="T_d0133_row4_col0" class="data row4 col0" >0.167083</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row5" class="row_heading level0 row5" >Uttar Pradesh</th>
#       <td id="T_d0133_row5_col0" class="data row5 col0" >0.165844</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row6" class="row_heading level0 row6" >Rajasthan</th>
#       <td id="T_d0133_row6_col0" class="data row6 col0" >0.152585</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row7" class="row_heading level0 row7" >Manipur</th>
#       <td id="T_d0133_row7_col0" class="data row7 col0" >0.147924</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row8" class="row_heading level0 row8" >Bihar</th>
#       <td id="T_d0133_row8_col0" class="data row8 col0" >0.132463</td>
#     </tr>
#     <tr>
#       <th id="T_d0133_level0_row9" class="row_heading level0 row9" >Jharkhand</th>
#       <td id="T_d0133_row9_col0" class="data row9 col0" >0.123332</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='text-align:center; border: 1px solid #ddd; padding: 10px;'><b>✅ Operational Stability: Biometric Usage (Bottom 10)</b></h3>
#                             Stress Ratio
# state
# Karnataka                       0.051977
# Kerala                           0.05114
# West Bengal                     0.047859
# Goa                             0.042523
# Himachal Pradesh                0.041984
# Sikkim                          0.040774
# Lakshadweep                     0.039872
# Puducherry                      0.037953
# Ladakh                          0.036405
# Andaman And Nicobar Islands     0.036011
# --------------------------------------------------
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>⚠️ High-Load Risk: Enrollment (Top 10)</b></h3>
# <style type="text/css">
# </style>
# <table id="T_1768c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1768c_level0_col0" class="col_heading level0 col0" >Stress Ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1768c_level0_row0" class="row_heading level0 row0" >Delhi</th>
#       <td id="T_1768c_row0_col0" class="data row0 col0" >0.348152</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row1" class="row_heading level0 row1" >Bihar</th>
#       <td id="T_1768c_row1_col0" class="data row1 col0" >0.346527</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row2" class="row_heading level0 row2" >Uttar Pradesh</th>
#       <td id="T_1768c_row2_col0" class="data row2 col0" >0.281268</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row3" class="row_heading level0 row3" >Chhattisgarh</th>
#       <td id="T_1768c_row3_col0" class="data row3 col0" >0.256350</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row4" class="row_heading level0 row4" >Manipur</th>
#       <td id="T_1768c_row4_col0" class="data row4 col0" >0.229125</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row5" class="row_heading level0 row5" >Jharkhand</th>
#       <td id="T_1768c_row5_col0" class="data row5 col0" >0.175712</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row6" class="row_heading level0 row6" >Maharashtra</th>
#       <td id="T_1768c_row6_col0" class="data row6 col0" >0.175152</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row7" class="row_heading level0 row7" >Chandigarh</th>
#       <td id="T_1768c_row7_col0" class="data row7 col0" >0.129211</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row8" class="row_heading level0 row8" >Haryana</th>
#       <td id="T_1768c_row8_col0" class="data row8 col0" >0.125646</td>
#     </tr>
#     <tr>
#       <th id="T_1768c_level0_row9" class="row_heading level0 row9" >West Bengal</th>
#       <td id="T_1768c_row9_col0" class="data row9 col0" >0.121668</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='text-align:center; border: 1px solid #ddd; padding: 10px;'><b>✅ Operational Stability: Enrollment (Bottom 10)</b></h3>
#                             Stress Ratio
# state
# Odisha                          0.016921
# Ladakh                          0.014365
# Mizoram                         0.014159
# Kerala                          0.010283
# Himachal Pradesh                0.008853
# Goa                             0.007069
# Sikkim                          0.006892
# Puducherry                      0.005568
# Andaman And Nicobar Islands     0.005522
# Lakshadweep                            0
# --------------------------------------------------
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>⚠️ High-Load Risk: Demographics (Top 10)</b></h3>
# <style type="text/css">
# </style>
# <table id="T_7ff93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ff93_level0_col0" class="col_heading level0 col0" >Stress Ratio</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ff93_level0_row0" class="row_heading level0 row0" >Delhi</th>
#       <td id="T_7ff93_row0_col0" class="data row0 col0" >0.279542</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row1" class="row_heading level0 row1" >Madhya Pradesh</th>
#       <td id="T_7ff93_row1_col0" class="data row1 col0" >0.262715</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row2" class="row_heading level0 row2" >Bihar</th>
#       <td id="T_7ff93_row2_col0" class="data row2 col0" >0.252445</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row3" class="row_heading level0 row3" >Meghalaya</th>
#       <td id="T_7ff93_row3_col0" class="data row3 col0" >0.225000</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row4" class="row_heading level0 row4" >Uttar Pradesh</th>
#       <td id="T_7ff93_row4_col0" class="data row4 col0" >0.198308</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row5" class="row_heading level0 row5" >Jharkhand</th>
#       <td id="T_7ff93_row5_col0" class="data row5 col0" >0.187183</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row6" class="row_heading level0 row6" >Rajasthan</th>
#       <td id="T_7ff93_row6_col0" class="data row6 col0" >0.143861</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row7" class="row_heading level0 row7" >Chhattisgarh</th>
#       <td id="T_7ff93_row7_col0" class="data row7 col0" >0.132625</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row8" class="row_heading level0 row8" >Haryana</th>
#       <td id="T_7ff93_row8_col0" class="data row8 col0" >0.128549</td>
#     </tr>
#     <tr>
#       <th id="T_7ff93_level0_row9" class="row_heading level0 row9" >Assam</th>
#       <td id="T_7ff93_row9_col0" class="data row9 col0" >0.112383</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='text-align:center; border: 1px solid #ddd; padding: 10px;'><b>✅ Operational Stability: Demographics (Bottom 10)</b></h3>
#                             Stress Ratio
# state
# Tamil Nadu                      0.015955
# Kerala                          0.008571
# Ladakh                          0.008086
# Andhra Pradesh                  0.007987
# Sikkim                          0.003231
# Himachal Pradesh                0.002928
# Puducherry                      0.002669
# Andaman And Nicobar Islands     0.002062
# Goa                             0.001085
# Lakshadweep                            0
# --------------------------------------------------

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Advanced Modeling: Infrastructure Stress Score</h3>
# </div>

# %%
state_area_km2 = {
    "Uttar Pradesh": 240928,"Maharashtra": 307713,"Madhya Pradesh": 308245,
    "Bihar": 94163,"Tamil Nadu": 130058,"Rajasthan": 342239,
    "Andhra Pradesh": 162975,"Gujarat": 196024,"Lakshadweep": 32,
    "Chhattisgarh": 135191,"Karnataka": 191791,"West Bengal": 88752,
    "Odisha": 155707,"Jharkhand": 79716,"Punjab": 50362,
    "Telangana": 112077,"Haryana": 44212,"Kerala": 38863,
    "Delhi": 1484,"Assam": 78438,"Jammu And Kashmir": 42241,
    "Uttarakhand": 53483,"Himachal Pradesh": 55673,"Tripura": 10486,
    "Manipur": 22327,"Mizoram": 21081,"Nagaland": 16579,
    "Meghalaya": 22429,"Chandigarh": 114,"Arunachal Pradesh": 83743,
    "Puducherry": 479,"Goa": 3702,
    "Dadra And Nagar Haveli And Daman And Diu": 603,
    "Sikkim": 7096,"Andaman And Nicobar Islands": 8249,"Ladakh": 59146,
}

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]

for total_col, title in zip(totals, titles):
    threshold = df[total_col].dropna().quantile(0.90)
    
    high_load_col = f"high_load_{total_col}"
    df[high_load_col] = df[total_col].where(df[total_col].notna())  # keep NaN
    df[high_load_col] = df[high_load_col].apply(lambda x: 1 if x >= threshold else 0 if pd.notna(x) else pd.NA)
    
    highload_df = (
        df.groupby("state")[high_load_col]
          .mean()
          .reset_index(name="high_load_ratio")
    )
    
    highload_df["area_km2"] = highload_df["state"].map(state_area_km2)
    highload_df = highload_df.dropna(subset=["area_km2"])
    
    highload_df["log_area"] = np.log(highload_df["area_km2"].clip(lower=1))
    
    highload_df["stress_score"] = highload_df["high_load_ratio"] / highload_df["log_area"]
    
    highload_df = highload_df.sort_values("stress_score", ascending=False)
    
    display_cols = ["state", "high_load_ratio", "area_km2", "log_area", "stress_score"]
    
    top_10_stress = highload_df[display_cols].head(10)
    bottom_10_stress = highload_df[display_cols].tail(10)
    
    display(Markdown(f"<h3 style='text-align:center;'><b>Top 10 States by Infrastructure Stress ({title})</b></h3>"))
    display(top_10_stress)
    
    display(Markdown(f"<h3 style='text-align:center;'><b>Bottom 10 States by Infrastructure Stress ({title})</b></h3>"))
    display(bottom_10_stress)
    print("\n" + "-"*60 + "\n")
# Out:
# <h3 style='text-align:center;'><b>Top 10 States by Infrastructure Stress (Biometric Usage)</b></h3>
#                                        state high_load_ratio  area_km2  \
# 8                                      Delhi        0.292858      1484
# 6                               Chhattisgarh        0.291736    135191
# 20                               Maharashtra        0.203474    307713
# 11                                   Haryana        0.167083     44212
# 21                                   Manipur        0.147924     22327
# 19                            Madhya Pradesh        0.181836    308245
# 33                             Uttar Pradesh        0.165844    240928
# 7   Dadra And Nagar Haveli And Daman And Diu        0.084399       603
# 5                                 Chandigarh        0.057867       114
# 28                                 Rajasthan        0.152585    342239
#
#     log_area stress_score
# 8   7.302496     0.040104
# 6  11.814444     0.024693
# 20 12.636923     0.016102
# 11 10.696752      0.01562
# 21 10.013552     0.014772
# 19  12.63865     0.014387
# 33 12.392253     0.013383
# 7   6.401917     0.013183
# 5   4.736198     0.012218
# 28 12.743265     0.011974
# <h3 style='text-align:center;'><b>Bottom 10 States by Infrastructure Stress (Biometric Usage)</b></h3>
#                           state high_load_ratio  area_km2  log_area  \
# 25                       Odisha         0.05843    155707 11.955731
# 16                       Kerala         0.05114     38863 10.567798
# 2             Arunachal Pradesh        0.053547     83743 11.335508
# 29                       Sikkim        0.040774      7096  8.867287
# 1                Andhra Pradesh         0.05351    162975 12.001352
# 15                    Karnataka        0.051977    191791 12.164162
# 35                  West Bengal        0.047859     88752 11.393601
# 0   Andaman And Nicobar Islands        0.036011      8249  9.017847
# 12             Himachal Pradesh        0.041984     55673 10.927251
# 17                       Ladakh        0.036405     59146 10.987764
#
#    stress_score
# 25     0.004887
# 16     0.004839
# 2      0.004724
# 29     0.004598
# 1      0.004459
# 15     0.004273
# 35     0.004201
# 0      0.003993
# 12     0.003842
# 17     0.003313
# ------------------------------------------------------------
# <h3 style='text-align:center;'><b>Top 10 States by Infrastructure Stress (Enrollment)</b></h3>
#             state high_load_ratio  area_km2  log_area stress_score
# 8           Delhi        0.348152      1484  7.302496     0.047676
# 4           Bihar        0.346527     94163 11.452783     0.030257
# 5      Chandigarh        0.129211       114  4.736198     0.027282
# 21        Manipur        0.229125     22327 10.013552     0.022882
# 33  Uttar Pradesh        0.281268    240928 12.392253     0.022697
# 6    Chhattisgarh         0.25635    135191 11.814444     0.021698
# 14      Jharkhand        0.175712     79716 11.286226     0.015569
# 20    Maharashtra        0.175152    307713 12.636923      0.01386
# 11        Haryana        0.125646     44212 10.696752     0.011746
# 35    West Bengal        0.121668     88752 11.393601     0.010679
# <h3 style='text-align:center;'><b>Bottom 10 States by Infrastructure Stress (Enrollment)</b></h3>
#                           state high_load_ratio  area_km2  log_area  \
# 23                      Mizoram        0.014159     21081  9.956127
# 25                       Odisha        0.016921    155707 11.955731
# 17                       Ladakh        0.014365     59146 10.987764
# 16                       Kerala        0.010283     38863 10.567798
# 26                   Puducherry        0.005568       479  6.171701
# 9                           Goa        0.007069      3702  8.216628
# 12             Himachal Pradesh        0.008853     55673 10.927251
# 29                       Sikkim        0.006892      7096  8.867287
# 0   Andaman And Nicobar Islands        0.005522      8249  9.017847
# 18                  Lakshadweep               0        32  3.465736
#
#    stress_score
# 23     0.001422
# 25     0.001415
# 17     0.001307
# 16     0.000973
# 26     0.000902
# 9       0.00086
# 12      0.00081
# 29     0.000777
# 0      0.000612
# 18            0
# ------------------------------------------------------------
# <h3 style='text-align:center;'><b>Top 10 States by Infrastructure Stress (Demographics)</b></h3>
#              state high_load_ratio  area_km2  log_area stress_score
# 8            Delhi        0.279542      1484  7.302496      0.03828
# 22       Meghalaya           0.225     22429  10.01811     0.022459
# 4            Bihar        0.252445     94163 11.452783     0.022042
# 19  Madhya Pradesh        0.262715    308245  12.63865     0.020787
# 14       Jharkhand        0.187183     79716 11.286226     0.016585
# 33   Uttar Pradesh        0.198308    240928 12.392253     0.016003
# 11         Haryana        0.128549     44212 10.696752     0.012018
# 28       Rajasthan        0.143861    342239 12.743265     0.011289
# 6     Chhattisgarh        0.132625    135191 11.814444     0.011226
# 5       Chandigarh        0.051491       114  4.736198     0.010872
# <h3 style='text-align:center;'><b>Bottom 10 States by Infrastructure Stress (Demographics)</b></h3>
#                           state high_load_ratio  area_km2  log_area  \
# 30                   Tamil Nadu        0.015955    130058 11.775736
# 16                       Kerala        0.008571     38863 10.567798
# 17                       Ladakh        0.008086     59146 10.987764
# 1                Andhra Pradesh        0.007987    162975 12.001352
# 26                   Puducherry        0.002669       479  6.171701
# 29                       Sikkim        0.003231      7096  8.867287
# 12             Himachal Pradesh        0.002928     55673 10.927251
# 0   Andaman And Nicobar Islands        0.002062      8249  9.017847
# 9                           Goa        0.001085      3702  8.216628
# 18                  Lakshadweep               0        32  3.465736
#
#    stress_score
# 30     0.001355
# 16     0.000811
# 17     0.000736
# 1      0.000666
# 26     0.000432
# 29     0.000364
# 12     0.000268
# 0      0.000229
# 9      0.000132
# 18            0
# ------------------------------------------------------------

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]

for total_col, title in zip(totals, titles):
    threshold = df[total_col].quantile(0.90)
    high_load_col = f"high_load_{total_col}"
    df[high_load_col] = (df[total_col] >= threshold).astype(int)
    
    highload_df = (
        df.groupby("state")[high_load_col]
          .mean()
          .reset_index(name="high_load_ratio")
    )
    
    highload_df["area_km2"] = highload_df["state"].map(state_area_km2)
    highload_df = highload_df.dropna(subset=["area_km2"])
    
    highload_df["log_area"] = np.log(highload_df["area_km2"].clip(lower=1))
    
    highload_df["stress_score"] = highload_df["high_load_ratio"] / highload_df["log_area"]
    
    top10 = highload_df.sort_values("stress_score", ascending=False).head(10)
    
    plt.figure(figsize=(10,5))
    top10.plot(
        x="state", y="stress_score",
        kind="bar", color="salmon", legend=False
    )
    plt.title(f"Top 10 States by Area-Regularized Stress ({title})")
    plt.ylabel("Stress Score")
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Macro-Geographical Segmentation</h3>
# </div>

# %%
north_states = [
    "Delhi", "Haryana", "Punjab", "Uttar Pradesh", "Uttarakhand", "Bihar",
    "Himachal Pradesh", "Jammu And Kashmir", "Ladakh", "Chandigarh"
]

south_states = [
    "Tamil Nadu", "Karnataka", "Kerala",
    "Andhra Pradesh", "Telangana",
    "Puducherry", "Lakshadweep", "Andaman And Nicobar Islands"
]

west_states = [
    "Maharashtra", "Gujarat", "Rajasthan", "Goa",
    "Dadra And Nagar Haveli And Daman And Diu"
]

east_states = [
    "West Bengal", "Odisha", "Jharkhand",
    "Assam", "Tripura", "Manipur", "Meghalaya",
    "Mizoram", "Nagaland", "Arunachal Pradesh", "Sikkim"
]

central_states = [
    "Madhya Pradesh", "Chhattisgarh"
]


df["region"] = None

df.loc[df["state"].isin(north_states), "region"] = "North"
df.loc[df["state"].isin(south_states), "region"] = "South"
df.loc[df["state"].isin(west_states), "region"] = "West"
df.loc[df["state"].isin(east_states), "region"] = "East"
df.loc[df["state"].isin(central_states), "region"] = "Central"

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]

for total_col, title in zip(totals, titles):
    region_usage = df.groupby("region")[total_col].sum()
    region_share = (region_usage / region_usage.sum()) * 100
    
    display(Markdown(f"<h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🌎 Regional Market Share: {title}</b></h3>"))
    
    share_df = pd.DataFrame(region_share.sort_values(ascending=False)).rename(columns={total_col: "National Share (%)"})
    display(share_df.style.format("{:.2f}%").background_gradient(cmap='Purples'))
    
    print("\n")
# Out:
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🌎 Regional Market Share: Biometric Usage</b></h3>
# <style type="text/css">
# #T_56435_row0_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_56435_row1_col0 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# #T_56435_row2_col0 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_56435_row3_col0, #T_56435_row4_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_56435">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56435_level0_col0" class="col_heading level0 col0" >National Share (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56435_level0_row0" class="row_heading level0 row0" >North</th>
#       <td id="T_56435_row0_col0" class="data row0 col0" >30.49%</td>
#     </tr>
#     <tr>
#       <th id="T_56435_level0_row1" class="row_heading level0 row1" >West</th>
#       <td id="T_56435_row1_col0" class="data row1 col0" >23.52%</td>
#     </tr>
#     <tr>
#       <th id="T_56435_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_56435_row2_col0" class="data row2 col0" >20.55%</td>
#     </tr>
#     <tr>
#       <th id="T_56435_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_56435_row3_col0" class="data row3 col0" >12.79%</td>
#     </tr>
#     <tr>
#       <th id="T_56435_level0_row4" class="row_heading level0 row4" >East</th>
#       <td id="T_56435_row4_col0" class="data row4 col0" >12.66%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🌎 Regional Market Share: Enrollment</b></h3>
# <style type="text/css">
# #T_00e41_row0_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_00e41_row1_col0 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_00e41_row2_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_00e41_row3_col0 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_00e41_row4_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_00e41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00e41_level0_col0" class="col_heading level0 col0" >National Share (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00e41_level0_row0" class="row_heading level0 row0" >North</th>
#       <td id="T_00e41_row0_col0" class="data row0 col0" >36.55%</td>
#     </tr>
#     <tr>
#       <th id="T_00e41_level0_row1" class="row_heading level0 row1" >West</th>
#       <td id="T_00e41_row1_col0" class="data row1 col0" >19.71%</td>
#     </tr>
#     <tr>
#       <th id="T_00e41_level0_row2" class="row_heading level0 row2" >South</th>
#       <td id="T_00e41_row2_col0" class="data row2 col0" >17.46%</td>
#     </tr>
#     <tr>
#       <th id="T_00e41_level0_row3" class="row_heading level0 row3" >East</th>
#       <td id="T_00e41_row3_col0" class="data row3 col0" >16.39%</td>
#     </tr>
#     <tr>
#       <th id="T_00e41_level0_row4" class="row_heading level0 row4" >Central</th>
#       <td id="T_00e41_row4_col0" class="data row4 col0" >9.90%</td>
#     </tr>
#   </tbody>
# </table>
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🌎 Regional Market Share: Demographics</b></h3>
# <style type="text/css">
# #T_9882e_row0_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_9882e_row1_col0 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_9882e_row2_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_9882e_row3_col0 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_9882e_row4_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_9882e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9882e_level0_col0" class="col_heading level0 col0" >National Share (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9882e_level0_row0" class="row_heading level0 row0" >North</th>
#       <td id="T_9882e_row0_col0" class="data row0 col0" >37.06%</td>
#     </tr>
#     <tr>
#       <th id="T_9882e_level0_row1" class="row_heading level0 row1" >East</th>
#       <td id="T_9882e_row1_col0" class="data row1 col0" >18.82%</td>
#     </tr>
#     <tr>
#       <th id="T_9882e_level0_row2" class="row_heading level0 row2" >West</th>
#       <td id="T_9882e_row2_col0" class="data row2 col0" >18.32%</td>
#     </tr>
#     <tr>
#       <th id="T_9882e_level0_row3" class="row_heading level0 row3" >South</th>
#       <td id="T_9882e_row3_col0" class="data row3 col0" >14.57%</td>
#     </tr>
#     <tr>
#       <th id="T_9882e_level0_row4" class="row_heading level0 row4" >Central</th>
#       <td id="T_9882e_row4_col0" class="data row4 col0" >11.23%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">District-Level Hotspot Identification</h3>
# </div>

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]
header_colors = ["#e8f5e9", "#e3f2fd", "#fff3e0"] # Green, Blue, Orange

for total_col, title, color in zip(totals, titles, header_colors):
    district_total = (
        df.groupby(["state", "district"])[total_col]
          .sum()
          .sort_values(ascending=False)
          .reset_index()
    )
    
    display(Markdown(f"<h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📍 Top 15 Service Hotspots: {title}</b></h3>"))
    
    top_districts = district_total.head(15).rename(columns={total_col: "Total Transactions"})
    
    styled_df = top_districts.style.format({"Total Transactions": "{:,.0f}"})\
                                    .background_gradient(subset=["Total Transactions"], cmap='YlGnBu')\
                                    .hide(axis='index')
    
    display(styled_df)
    print("\n" + "-"*70 + "\n")
# Out:
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📍 Top 15 Service Hotspots: Biometric Usage</b></h3>
# <style type="text/css">
# #T_c01b2_row0_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_c01b2_row1_col2 {
#   background-color: #11246b;
#   color: #f1f1f1;
# }
# #T_c01b2_row2_col2 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_c01b2_row3_col2 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_c01b2_row4_col2 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_c01b2_row5_col2 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_c01b2_row6_col2 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_c01b2_row7_col2, #T_c01b2_row8_col2 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_c01b2_row9_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_c01b2_row10_col2 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_c01b2_row11_col2 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_c01b2_row12_col2 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_c01b2_row13_col2 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_c01b2_row14_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_c01b2">
#   <thead>
#     <tr>
#       <th id="T_c01b2_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_c01b2_level0_col1" class="col_heading level0 col1" >district</th>
#       <th id="T_c01b2_level0_col2" class="col_heading level0 col2" >Total Transactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c01b2_row0_col0" class="data row0 col0" >Maharashtra</td>
#       <td id="T_c01b2_row0_col1" class="data row0 col1" >Pune</td>
#       <td id="T_c01b2_row0_col2" class="data row0 col2" >702,689</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row1_col0" class="data row1 col0" >Maharashtra</td>
#       <td id="T_c01b2_row1_col1" class="data row1 col1" >Thane</td>
#       <td id="T_c01b2_row1_col2" class="data row1 col2" >688,809</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row2_col0" class="data row2 col0" >Maharashtra</td>
#       <td id="T_c01b2_row2_col1" class="data row2 col1" >Nashik</td>
#       <td id="T_c01b2_row2_col2" class="data row2 col2" >667,911</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row3_col0" class="data row3 col0" >Maharashtra</td>
#       <td id="T_c01b2_row3_col1" class="data row3 col1" >Jalgaon</td>
#       <td id="T_c01b2_row3_col2" class="data row3 col2" >473,615</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row4_col0" class="data row4 col0" >Gujarat</td>
#       <td id="T_c01b2_row4_col1" class="data row4 col1" >Ahmedabad</td>
#       <td id="T_c01b2_row4_col2" class="data row4 col2" >470,105</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row5_col0" class="data row5 col0" >Maharashtra</td>
#       <td id="T_c01b2_row5_col1" class="data row5 col1" >Mumbai</td>
#       <td id="T_c01b2_row5_col2" class="data row5 col2" >460,761</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row6_col0" class="data row6 col0" >Rajasthan</td>
#       <td id="T_c01b2_row6_col1" class="data row6 col1" >Jaipur</td>
#       <td id="T_c01b2_row6_col2" class="data row6 col2" >434,854</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row7_col0" class="data row7 col0" >Delhi</td>
#       <td id="T_c01b2_row7_col1" class="data row7 col1" >North West Delhi</td>
#       <td id="T_c01b2_row7_col2" class="data row7 col2" >429,407</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row8_col0" class="data row8 col0" >Andhra Pradesh</td>
#       <td id="T_c01b2_row8_col1" class="data row8 col1" >Kurnool</td>
#       <td id="T_c01b2_row8_col2" class="data row8 col2" >428,846</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row9_col0" class="data row9 col0" >Maharashtra</td>
#       <td id="T_c01b2_row9_col1" class="data row9 col1" >Ahmadnagar</td>
#       <td id="T_c01b2_row9_col2" class="data row9 col2" >411,366</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row10_col0" class="data row10 col0" >Maharashtra</td>
#       <td id="T_c01b2_row10_col1" class="data row10 col1" >Nagpur</td>
#       <td id="T_c01b2_row10_col2" class="data row10 col2" >403,325</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row11_col0" class="data row11 col0" >Maharashtra</td>
#       <td id="T_c01b2_row11_col1" class="data row11 col1" >Nanded</td>
#       <td id="T_c01b2_row11_col2" class="data row11 col2" >395,473</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row12_col0" class="data row12 col0" >Maharashtra</td>
#       <td id="T_c01b2_row12_col1" class="data row12 col1" >Amravati</td>
#       <td id="T_c01b2_row12_col2" class="data row12 col2" >387,192</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row13_col0" class="data row13 col0" >Maharashtra</td>
#       <td id="T_c01b2_row13_col1" class="data row13 col1" >Solapur</td>
#       <td id="T_c01b2_row13_col2" class="data row13 col2" >382,424</td>
#     </tr>
#     <tr>
#       <td id="T_c01b2_row14_col0" class="data row14 col0" >Maharashtra</td>
#       <td id="T_c01b2_row14_col1" class="data row14 col1" >Yavatmal</td>
#       <td id="T_c01b2_row14_col2" class="data row14 col2" >374,782</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📍 Top 15 Service Hotspots: Enrollment</b></h3>
# <style type="text/css">
# #T_cccb5_row0_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_cccb5_row1_col2 {
#   background-color: #11246b;
#   color: #f1f1f1;
# }
# #T_cccb5_row2_col2 {
#   background-color: #2356a4;
#   color: #f1f1f1;
# }
# #T_cccb5_row3_col2 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_cccb5_row4_col2 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_cccb5_row5_col2 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_cccb5_row6_col2 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_cccb5_row7_col2 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_cccb5_row8_col2 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_cccb5_row9_col2, #T_cccb5_row10_col2 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_cccb5_row11_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_cccb5_row12_col2 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_cccb5_row13_col2 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_cccb5_row14_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_cccb5">
#   <thead>
#     <tr>
#       <th id="T_cccb5_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_cccb5_level0_col1" class="col_heading level0 col1" >district</th>
#       <th id="T_cccb5_level0_col2" class="col_heading level0 col2" >Total Transactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cccb5_row0_col0" class="data row0 col0" >Maharashtra</td>
#       <td id="T_cccb5_row0_col1" class="data row0 col1" >Thane</td>
#       <td id="T_cccb5_row0_col2" class="data row0 col2" >458,771</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row1_col0" class="data row1 col0" >Maharashtra</td>
#       <td id="T_cccb5_row1_col1" class="data row1 col1" >Pune</td>
#       <td id="T_cccb5_row1_col2" class="data row1 col2" >450,169</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row2_col0" class="data row2 col0" >West Bengal</td>
#       <td id="T_cccb5_row2_col1" class="data row2 col1" >South 24 Parganas</td>
#       <td id="T_cccb5_row2_col2" class="data row2 col2" >412,146</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row3_col0" class="data row3 col0" >West Bengal</td>
#       <td id="T_cccb5_row3_col1" class="data row3 col1" >Murshidabad</td>
#       <td id="T_cccb5_row3_col2" class="data row3 col2" >386,346</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row4_col0" class="data row4 col0" >Gujarat</td>
#       <td id="T_cccb5_row4_col1" class="data row4 col1" >Surat</td>
#       <td id="T_cccb5_row4_col2" class="data row4 col2" >369,496</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row5_col0" class="data row5 col0" >Delhi</td>
#       <td id="T_cccb5_row5_col1" class="data row5 col1" >North West Delhi</td>
#       <td id="T_cccb5_row5_col2" class="data row5 col2" >321,884</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row6_col0" class="data row6 col0" >Karnataka</td>
#       <td id="T_cccb5_row6_col1" class="data row6 col1" >Bengaluru</td>
#       <td id="T_cccb5_row6_col2" class="data row6 col2" >309,235</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row7_col0" class="data row7 col0" >West Bengal</td>
#       <td id="T_cccb5_row7_col1" class="data row7 col1" >North 24 Parganas</td>
#       <td id="T_cccb5_row7_col2" class="data row7 col2" >304,869</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row8_col0" class="data row8 col0" >Rajasthan</td>
#       <td id="T_cccb5_row8_col1" class="data row8 col1" >Jaipur</td>
#       <td id="T_cccb5_row8_col2" class="data row8 col2" >285,007</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row9_col0" class="data row9 col0" >Gujarat</td>
#       <td id="T_cccb5_row9_col1" class="data row9 col1" >Ahmedabad</td>
#       <td id="T_cccb5_row9_col2" class="data row9 col2" >280,238</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row10_col0" class="data row10 col0" >West Bengal</td>
#       <td id="T_cccb5_row10_col1" class="data row10 col1" >Uttar Dinajpur</td>
#       <td id="T_cccb5_row10_col2" class="data row10 col2" >280,058</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row11_col0" class="data row11 col0" >Maharashtra</td>
#       <td id="T_cccb5_row11_col1" class="data row11 col1" >Solapur</td>
#       <td id="T_cccb5_row11_col2" class="data row11 col2" >277,294</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row12_col0" class="data row12 col0" >Bihar</td>
#       <td id="T_cccb5_row12_col1" class="data row12 col1" >East Champaran</td>
#       <td id="T_cccb5_row12_col2" class="data row12 col2" >265,270</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row13_col0" class="data row13 col0" >Bihar</td>
#       <td id="T_cccb5_row13_col1" class="data row13 col1" >Patna</td>
#       <td id="T_cccb5_row13_col2" class="data row13 col2" >257,663</td>
#     </tr>
#     <tr>
#       <td id="T_cccb5_row14_col0" class="data row14 col0" >Maharashtra</td>
#       <td id="T_cccb5_row14_col1" class="data row14 col1" >Nashik</td>
#       <td id="T_cccb5_row14_col2" class="data row14 col2" >254,804</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📍 Top 15 Service Hotspots: Demographics</b></h3>
# <style type="text/css">
# #T_1888c_row0_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_1888c_row1_col2 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_1888c_row2_col2 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_1888c_row3_col2 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_1888c_row4_col2 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_1888c_row5_col2 {
#   background-color: #caeab4;
#   color: #000000;
# }
# #T_1888c_row6_col2 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_1888c_row7_col2 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_1888c_row8_col2 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_1888c_row9_col2 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_1888c_row10_col2 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_1888c_row11_col2 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_1888c_row12_col2 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_1888c_row13_col2 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_1888c_row14_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_1888c">
#   <thead>
#     <tr>
#       <th id="T_1888c_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_1888c_level0_col1" class="col_heading level0 col1" >district</th>
#       <th id="T_1888c_level0_col2" class="col_heading level0 col2" >Total Transactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1888c_row0_col0" class="data row0 col0" >Maharashtra</td>
#       <td id="T_1888c_row0_col1" class="data row0 col1" >Thane</td>
#       <td id="T_1888c_row0_col2" class="data row0 col2" >55,640</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row1_col0" class="data row1 col0" >Bihar</td>
#       <td id="T_1888c_row1_col1" class="data row1 col1" >Sitamarhi</td>
#       <td id="T_1888c_row1_col2" class="data row1 col2" >47,267</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row2_col0" class="data row2 col0" >West Bengal</td>
#       <td id="T_1888c_row2_col1" class="data row2 col1" >Murshidabad</td>
#       <td id="T_1888c_row2_col2" class="data row2 col2" >45,901</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row3_col0" class="data row3 col0" >Uttar Pradesh</td>
#       <td id="T_1888c_row3_col1" class="data row3 col1" >Bahraich</td>
#       <td id="T_1888c_row3_col2" class="data row3 col2" >43,426</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row4_col0" class="data row4 col0" >West Bengal</td>
#       <td id="T_1888c_row4_col1" class="data row4 col1" >South 24 Parganas</td>
#       <td id="T_1888c_row4_col2" class="data row4 col2" >42,659</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row5_col0" class="data row5 col0" >Maharashtra</td>
#       <td id="T_1888c_row5_col1" class="data row5 col1" >Pune</td>
#       <td id="T_1888c_row5_col2" class="data row5 col2" >39,737</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row6_col0" class="data row6 col0" >Rajasthan</td>
#       <td id="T_1888c_row6_col1" class="data row6 col1" >Jaipur</td>
#       <td id="T_1888c_row6_col2" class="data row6 col2" >39,383</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row7_col0" class="data row7 col0" >Karnataka</td>
#       <td id="T_1888c_row7_col1" class="data row7 col1" >Bengaluru</td>
#       <td id="T_1888c_row7_col2" class="data row7 col2" >38,208</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row8_col0" class="data row8 col0" >West Bengal</td>
#       <td id="T_1888c_row8_col1" class="data row8 col1" >North 24 Parganas</td>
#       <td id="T_1888c_row8_col2" class="data row8 col2" >36,074</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row9_col0" class="data row9 col0" >Bihar</td>
#       <td id="T_1888c_row9_col1" class="data row9 col1" >East Champaran</td>
#       <td id="T_1888c_row9_col2" class="data row9 col2" >35,797</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row10_col0" class="data row10 col0" >Bihar</td>
#       <td id="T_1888c_row10_col1" class="data row10 col1" >West Champaran</td>
#       <td id="T_1888c_row10_col2" class="data row10 col2" >35,480</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row11_col0" class="data row11 col0" >Uttar Pradesh</td>
#       <td id="T_1888c_row11_col1" class="data row11 col1" >Sitapur</td>
#       <td id="T_1888c_row11_col2" class="data row11 col2" >35,340</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row12_col0" class="data row12 col0" >Uttar Pradesh</td>
#       <td id="T_1888c_row12_col1" class="data row12 col1" >Agra</td>
#       <td id="T_1888c_row12_col2" class="data row12 col2" >35,204</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row13_col0" class="data row13 col0" >Telangana</td>
#       <td id="T_1888c_row13_col1" class="data row13 col1" >Hyderabad</td>
#       <td id="T_1888c_row13_col2" class="data row13 col2" >35,095</td>
#     </tr>
#     <tr>
#       <td id="T_1888c_row14_col0" class="data row14 col0" >Uttar Pradesh</td>
#       <td id="T_1888c_row14_col1" class="data row14 col1" >Bareilly</td>
#       <td id="T_1888c_row14_col2" class="data row14 col2" >34,749</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Intra-State Heterogeneity & Service Disparity</h3>
# </div>

# %%
totals = ["total_biometrics", "total_enrollment", "total_demographics"]
titles = ["Biometric Usage", "Enrollment", "Demographics"]
bg_colors = ["#f1f8e9", "#e3f2fd", "#fff3e0"] # Green, Blue, Orange

for total_col, title, color in zip(totals, titles, bg_colors):
    district_variation = (
        df.groupby("state")[total_col]
          .std()
          .sort_values(ascending=False)
          .reset_index()
    )
    
    display(Markdown(f"<h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📊 Regional Disparity Leaderboard: {title}</b></h3></h3>"))
    
    variation_df = district_variation.head(10).rename(columns={total_col: "Inter-District Std Dev"})
    
    styled_v_df = variation_df.style.format({"Inter-District Std Dev": "{:,.2f}"})\
                                      .background_gradient(cmap='Purples')\
                                      .hide(axis='index')
    
    display(styled_v_df)
    print("\n" + "—"*70 + "\n")
# Out:
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📊 Regional Disparity Leaderboard: Biometric Usage</b></h3></h3>
# <style type="text/css">
# #T_041fa_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_041fa_row1_col1 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_041fa_row2_col1 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_041fa_row3_col1 {
#   background-color: #e8e7f2;
#   color: #000000;
# }
# #T_041fa_row4_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_041fa_row5_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_041fa_row6_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_041fa_row7_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_041fa_row8_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_041fa_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_041fa">
#   <thead>
#     <tr>
#       <th id="T_041fa_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_041fa_level0_col1" class="col_heading level0 col1" >Inter-District Std Dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_041fa_row0_col0" class="data row0 col0" >Delhi</td>
#       <td id="T_041fa_row0_col1" class="data row0 col1" >689.58</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row1_col0" class="data row1 col0" >Madhya Pradesh</td>
#       <td id="T_041fa_row1_col1" class="data row1 col1" >347.90</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row2_col0" class="data row2 col0" >Chandigarh</td>
#       <td id="T_041fa_row2_col1" class="data row2 col1" >280.53</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row3_col0" class="data row3 col0" >Chhattisgarh</td>
#       <td id="T_041fa_row3_col1" class="data row3 col1" >269.43</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row4_col0" class="data row4 col0" >Haryana</td>
#       <td id="T_041fa_row4_col1" class="data row4 col1" >262.82</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row5_col0" class="data row5 col0" >Uttar Pradesh</td>
#       <td id="T_041fa_row5_col1" class="data row5 col1" >222.20</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row6_col0" class="data row6 col0" >Jharkhand</td>
#       <td id="T_041fa_row6_col1" class="data row6 col1" >215.68</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row7_col0" class="data row7 col0" >Maharashtra</td>
#       <td id="T_041fa_row7_col1" class="data row7 col1" >202.13</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row8_col0" class="data row8 col0" >Bihar</td>
#       <td id="T_041fa_row8_col1" class="data row8 col1" >198.69</td>
#     </tr>
#     <tr>
#       <td id="T_041fa_row9_col0" class="data row9 col0" >Manipur</td>
#       <td id="T_041fa_row9_col1" class="data row9 col1" >185.68</td>
#     </tr>
#   </tbody>
# </table>
# ——————————————————————————————————————————————————————————————————————
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📊 Regional Disparity Leaderboard: Enrollment</b></h3></h3>
# <style type="text/css">
# #T_96d81_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_96d81_row1_col1 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_96d81_row2_col1 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_96d81_row3_col1 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_96d81_row4_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_96d81_row5_col1 {
#   background-color: #f5f3f8;
#   color: #000000;
# }
# #T_96d81_row6_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_96d81_row7_col1 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_96d81_row8_col1, #T_96d81_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_96d81">
#   <thead>
#     <tr>
#       <th id="T_96d81_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_96d81_level0_col1" class="col_heading level0 col1" >Inter-District Std Dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96d81_row0_col0" class="data row0 col0" >Delhi</td>
#       <td id="T_96d81_row0_col1" class="data row0 col1" >696.82</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row1_col0" class="data row1 col0" >Chhattisgarh</td>
#       <td id="T_96d81_row1_col1" class="data row1 col1" >319.93</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row2_col0" class="data row2 col0" >Uttar Pradesh</td>
#       <td id="T_96d81_row2_col1" class="data row2 col1" >236.21</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row3_col0" class="data row3 col0" >Haryana</td>
#       <td id="T_96d81_row3_col1" class="data row3 col1" >223.94</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row4_col0" class="data row4 col0" >Jharkhand</td>
#       <td id="T_96d81_row4_col1" class="data row4 col1" >186.24</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row5_col0" class="data row5 col0" >Rajasthan</td>
#       <td id="T_96d81_row5_col1" class="data row5 col1" >178.97</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row6_col0" class="data row6 col0" >Madhya Pradesh</td>
#       <td id="T_96d81_row6_col1" class="data row6 col1" >173.54</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row7_col0" class="data row7 col0" >Chandigarh</td>
#       <td id="T_96d81_row7_col1" class="data row7 col1" >171.75</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row8_col0" class="data row8 col0" >Bihar</td>
#       <td id="T_96d81_row8_col1" class="data row8 col1" >140.74</td>
#     </tr>
#     <tr>
#       <td id="T_96d81_row9_col0" class="data row9 col0" >Uttarakhand</td>
#       <td id="T_96d81_row9_col1" class="data row9 col1" >138.14</td>
#     </tr>
#   </tbody>
# </table>
# ——————————————————————————————————————————————————————————————————————
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📊 Regional Disparity Leaderboard: Demographics</b></h3></h3>
# <style type="text/css">
# #T_d6c54_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_d6c54_row1_col1 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_d6c54_row2_col1 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_d6c54_row3_col1 {
#   background-color: #e9e8f2;
#   color: #000000;
# }
# #T_d6c54_row4_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_d6c54_row5_col1, #T_d6c54_row6_col1 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_d6c54_row7_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_d6c54_row8_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_d6c54_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_d6c54">
#   <thead>
#     <tr>
#       <th id="T_d6c54_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_d6c54_level0_col1" class="col_heading level0 col1" >Inter-District Std Dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6c54_row0_col0" class="data row0 col0" >Meghalaya</td>
#       <td id="T_d6c54_row0_col1" class="data row0 col1" >123.32</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row1_col0" class="data row1 col0" >Delhi</td>
#       <td id="T_d6c54_row1_col1" class="data row1 col1" >83.28</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row2_col0" class="data row2 col0" >Uttar Pradesh</td>
#       <td id="T_d6c54_row2_col1" class="data row2 col1" >52.89</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row3_col0" class="data row3 col0" >Madhya Pradesh</td>
#       <td id="T_d6c54_row3_col1" class="data row3 col1" >44.63</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row4_col0" class="data row4 col0" >Bihar</td>
#       <td id="T_d6c54_row4_col1" class="data row4 col1" >39.76</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row5_col0" class="data row5 col0" >Haryana</td>
#       <td id="T_d6c54_row5_col1" class="data row5 col1" >38.27</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row6_col0" class="data row6 col0" >Nagaland</td>
#       <td id="T_d6c54_row6_col1" class="data row6 col1" >37.85</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row7_col0" class="data row7 col0" >Gujarat</td>
#       <td id="T_d6c54_row7_col1" class="data row7 col1" >32.57</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row8_col0" class="data row8 col0" >Assam</td>
#       <td id="T_d6c54_row8_col1" class="data row8 col1" >31.23</td>
#     </tr>
#     <tr>
#       <td id="T_d6c54_row9_col0" class="data row9 col0" >Manipur</td>
#       <td id="T_d6c54_row9_col1" class="data row9 col1" >29.55</td>
#     </tr>
#   </tbody>
# </table>
# ——————————————————————————————————————————————————————————————————————

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Age-Specific Transaction Profiles</h3>
# </div>

# %%
totals_cols = [
    ["bio_age_5_17","bio_age_17_"],
    ["demo_age_5_17","demo_age_17_"],
    ["age_0_5","age_5_17","age_18_greater"]
]
titles = ["Biometric Usage", "Enrollment", "Demographics"]
labels_list = [
    ["Children (5–17)", "Adults (17+)"],
    ["Children (5–17)", "Adults (17+)"],
    ["Age 0–5", "Age 5–17", "Age 18+"]
]

for cols, title, labels in zip(totals_cols, titles, labels_list):
    state_age = df.groupby("state")[cols].sum().reset_index()
    
    state_age["total"] = state_age[cols].sum(axis=1)
    state_age = state_age.sort_values("total", ascending=False)
    
    plt.figure(figsize=(16,8))
    
    bottom = np.zeros(len(state_age))
    for col, label in zip(cols, labels):
        plt.bar(state_age["state"], state_age[col], bottom=bottom, label=label)
        bottom += state_age[col]
    
    plt.title(f"State-wise {title} by Age Group (Absolute, Sorted)")
    plt.ylabel("Total Transactions")
    plt.xticks(rotation=90)
    plt.legend()
    plt.grid(True, axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Temporal Trend Analysis & Service Seasonality</h3>
# </div>

# %%
df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month

monthly_bio = df.groupby(["year","month"])["total_biometrics"].sum(min_count=1).reset_index()
monthly_enroll = df.groupby(["year","month"])["total_enrollment"].sum(min_count=1).reset_index()
monthly_demo = df.groupby(["year","month"])["total_demographics"].sum(min_count=1).reset_index()

for m_df in [monthly_bio, monthly_enroll, monthly_demo]:
    m_df["date"] = pd.to_datetime(dict(year=m_df["year"], month=m_df["month"], day=1))
    m_df.sort_values("date", inplace=True)

display(Markdown("<h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📈 National Aadhaar Usage Timeline (2025)</b></h3>"))

plt.figure(figsize=(14,7))

plt.plot(monthly_bio["date"], monthly_bio["total_biometrics"], marker="o", markersize=8, 
         linewidth=3, label="Biometrics", color="#2e7d32")
plt.plot(monthly_enroll["date"], monthly_enroll["total_enrollment"], marker="s", markersize=8, 
         linewidth=3, label="Enrollment", color="#1565c0")
plt.plot(monthly_demo["date"], monthly_demo["total_demographics"], marker="^", markersize=8, 
         linewidth=3, label="Demographics", color="#ef6c00")

plt.title("Monthly Aadhaar Transaction Velocity", fontsize=18, fontweight='bold', pad=25)
plt.xlabel("Month of Observation", fontsize=12)
plt.ylabel("Total Transaction Volume", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.3)
plt.xticks(rotation=45)
plt.legend(frameon=True, fontsize=12, loc='upper left', shadow=True)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# <h3 style='text-align:center; padding: 12px; border-radius: 8px;'><b>📈 National Aadhaar Usage Timeline (2025)</b></h3>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     border-radius: 8px;
#     padding: 16px 20px;
#     margin: 20px 0;
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h3 style="margin: 0;
#         color: white;
#         font-weight: 600;
#         font-size: 1.3em;
#         letter-spacing: 0.5px;">Predictive Forecasting & Resource Planning</h3>
# </div>

# %%
df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month

monthly = (
    df.groupby(["year", "month"])[
        ["total_biometrics", "total_enrollment", "total_demographics"]
    ]
    .sum(min_count=1) 
    .reset_index()
)

monthly["date"] = pd.to_datetime(
    dict(year=monthly["year"], month=monthly["month"], day=1)
)
monthly = monthly.sort_values("date")

monthly_cols = [
    ("total_biometrics", "Biometrics", "#2e7d32"),
    ("total_enrollment", "Enrollment", "#1565c0"),
    ("total_demographics", "Demographics", "#ef6c00")
]

monthly_drift = 0.001 

for col, label, color in monthly_cols:
    monthly_col = monthly[["date", col]].dropna()
    
    baseline = monthly_col.tail(6)[col].mean()
    
    future_dates = pd.date_range(
        start=monthly_col["date"].iloc[-1] + pd.offsets.MonthBegin(1),
        periods=60, freq="MS"
    )
    
    future = pd.DataFrame({"date": future_dates})
    future["forecast"] = baseline * (1 + monthly_drift) ** np.arange(1, 61)
    
    display(Markdown(f"<h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🔮 {label} Demand Projection (60-Month Forecast)</b></h3>"))

    plt.figure(figsize=(14,6))
    plt.plot(monthly_col["date"], monthly_col[col], marker="o", label="Historical Baseline", color=color, linewidth=2)
    plt.plot(future["date"], future["forecast"], linestyle="--", label="Projected Growth", color="#d32f2f", alpha=0.8)
    
    plt.title(f"Aadhaar {label}: Long-Term Trend Forecast", fontsize=15, fontweight='bold')
    plt.xlabel("Timeline", fontsize=12)
    plt.ylabel("Transaction Volume", fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.3)
    plt.legend(frameon=True, shadow=True)
    
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.show()
# Out:
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🔮 Biometrics Demand Projection (60-Month Forecast)</b></h3>
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🔮 Enrollment Demand Projection (60-Month Forecast)</b></h3>
# <h3 style='text-align:center; padding: 10px; border-radius: 5px;'><b>🔮 Demographics Demand Projection (60-Month Forecast)</b></h3>
